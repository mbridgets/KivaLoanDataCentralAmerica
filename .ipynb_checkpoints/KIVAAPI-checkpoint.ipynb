# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
url = 'https://api.kivaws.org/graphql?variables=null&operationName=null&query=%7B%0A%20%20lend%20%7B%0A%20%20%20%20loans(filters%3A%20%7Bcountry%3A%20%5B%22NI%22%2C%20%22SV%22%2C%20%22HN%22%2C%20%22CR%22%5D%7D%2C%20%2C%20limit%3A%20626)%20%7B%0A%20%20%20%20%20%20totalCount%0A%20%20%20%20%20%20values%20%7B%0A%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20loanAmount%0A%20%20%20%20%20%20%20%20image%20%7B%0A%20%20%20%20%20%20%20%20%20%20url(presetSize%3A%20small)%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20activity%20%7B%0A%20%20%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20geocode%20%7B%0A%20%20%20%20%20%20%20%20%20%20country%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20isoCode%0A%20%20%20%20%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20lenders(limit%3A%200)%20%7B%0A%20%20%20%20%20%20%20%20%20%20totalCount%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20...%20on%20LoanPartner%20%7B%0A%20%20%20%20%20%20%20%20%20%20partnerName%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20...%20on%20LoanDirect%20%7B%0A%20%20%20%20%20%20%20%20%20%20trusteeName%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%7D%0A%7D%0A'

# %%
req=requests.get(url)
response = req.json()

# %%
response
# Out:
# {'data': {'lend': {'loans': {'totalCount': 626,
#     'values': [{'name': 'Todo Poderoso Group',
#       'loanAmount': '850.00',
#       'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/03fd7f2d962062b657ba1507bc79e702.jpg'},
#       'activity': {'name': 'Retail'},
#       'geocode': {'country': {'isoCode': 'NI', 'name': 'Nicaragua'}},
#       'lenders': {'totalCount': 17},
#       'partnerName': 'FUNDENUSE'},
#      {'name': 'Magdaleno Antonio',
#       'loanAmount': '800.00',
#       'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/f1825dcbb6975d13ce58fbb34e309d2c.jpg'},
#       'activity': {'name': 'Farming'},
#       'geocode': {'country': {'isoCode': 'SV', 'name': 'El Salvador'}},
#       'lenders': {'totalCount': 9},
#       'partnerName': 'CrediCampo'},
#      {'name': 'Willian Ernesto',
#       'loanAmount': '1000.00',
#       'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/7829e5f41411ab6baba591916d4fb398.jpg'},
# ...

# %%
json = json.loads(json.dumps(response))
clean_json = json['data']['lend']['loans']['values']

# %%
df = pd.DataFrame(clean_json)
df
# Out:
#                    name loanAmount  \
# 0   Todo Poderoso Group     850.00
# 1     Magdaleno Antonio     800.00
# 2       Willian Ernesto    1000.00
# 3            Blanca Luz     450.00
# 4        Roxana Marisol     800.00
# ..                  ...        ...
# 95        Juan Virgilio     875.00
# 96            Alexander    1725.00
# 97       Carlos Gerardo     850.00
# 98            Alexander     850.00
# 99          Danis Obeth     850.00
#
#                                                 image  \
# 0   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 1   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 2   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 3   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 4   {'url': 'https://www-kiva-org-0.freetls.fastly...
# ..                                                ...
# 95  {'url': 'https://www-kiva-org-0.freetls.fastly...
# 96  {'url': 'https://www-kiva-org-0.freetls.fastly...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                    name loanAmount  \
# 0   Todo Poderoso Group     850.00
# 1     Magdaleno Antonio     800.00
# 2       Willian Ernesto    1000.00
# 3            Blanca Luz     450.00
# 4        Roxana Marisol     800.00
# ..                  ...        ...
# 95        Juan Virgilio     875.00
# 96            Alexander    1725.00
# 97       Carlos Gerardo     850.00
# 98            Alexander     850.00
# 99          Danis Obeth     850.00
#
#                                                 image  \
# 0   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 1   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 2   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 3   {'url': 'https://www-kiva-org-0.freetls.fastly...
# 4   {'url': 'https://www-kiva-org-0.freetls.fastly...
# ..                                                ...
# 95  {'url': 'https://www-kiva-org-0.freetls.fastly...
# 96  {'url': 'https://www-kiva-org-0.freetls.fastly...
# ...
