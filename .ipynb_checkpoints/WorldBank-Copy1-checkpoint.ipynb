# %%
#import all libraries needed 
import os
import pandas as pd

# from api_keys import gkey
import gmaps
import gmaps.datasets
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from sqlalchemy import create_engine

# %%
#Get Path to get to the Datasets
WorldBankpath = os.path.join('Data Sets', 'WorldBank.csv')

# %%
#read the files 
WorldBank = pd.read_csv(WorldBankpath)

# %%
WorldBank.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1990 [YR1990]', '2000 [YR2000]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %%
WorldBankDrop = WorldBank[['Country Name', 'Country Code', 'Series Name','2011 [YR2011]', '2012 [YR2012]',
       '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
       '2017 [YR2017]', '2018 [YR2018]']]

# %%
WorldBankDrop
# Out:
#                                          Country Name Country Code  \
# 0                           Latin America & Caribbean          LCN
# 1                           Latin America & Caribbean          LCN
# 2                           Latin America & Caribbean          LCN
# 3                           Latin America & Caribbean          LCN
# 4                           Latin America & Caribbean          LCN
# ..                                                ...          ...
# 275                                               NaN          NaN
# 276                                               NaN          NaN
# 277                                               NaN          NaN
# 278  Data from database: World Development Indicators          NaN
# 279                          Last Updated: 09/16/2020          NaN
#
#                                            Series Name     2011 [YR2011]  \
# 0                                    Population, total         596538911
# 1                         Population growth (annual %)   1.1198476558079
# 2                                Surface area (sq. km)  20425484.4078087
# 3    Population density (people per sq. km of land ...  29.7641321747825
# 4    Poverty headcount ratio at national poverty li...                ..
# ..                                                 ...               ...
# 275                                                NaN               NaN
# 276                                                NaN               NaN
# 277                                                NaN               NaN
# 278                                                NaN               NaN
# 279                                                NaN               NaN
#
#         2012 [YR2012]     2013 [YR2013]     2014 [YR2014]     2015 [YR2015]  \
# 0           603097381         609600087         616002686         622301089
# 1    1.09942031928911  1.07821824548762   1.0502949616541  1.02246356114104
# 2    20425482.3765587  20425483.3921837  20425483.3921837  20425483.3921837
# 3    30.0919866753081  30.4198271919214  30.7396318936835  31.0539334286253
# 4                  ..                ..                ..                ..
# ..                ...               ...               ...               ...
# 275               NaN               NaN               NaN               NaN
# 276               NaN               NaN               NaN               NaN
# 277               NaN               NaN               NaN               NaN
# 278               NaN               NaN               NaN               NaN
# 279               NaN               NaN               NaN               NaN
#
#          2016 [YR2016]      2017 [YR2017]      2018 [YR2018]
# 0            628484873          634545282          640454810
# 1    0.993696477365475  0.964288761807637  0.931301227451243
# 2     20426078.3765625   20426078.3765625   20425545.9765625
# 3      31.362515271189   31.6649404813693   31.9606855829336
# 4                   ..                 ..                 ..
# ..                 ...                ...                ...
# 275                NaN                NaN                NaN
# 276                NaN                NaN                NaN
# 277                NaN                NaN                NaN
# 278                NaN                NaN                NaN
# 279                NaN                NaN                NaN
#
# [280 rows x 11 columns]

# %%
WorldBank['Country Code'].value_counts()
# Out:
# CRI    55
# NIC    55
# SLV    55
# LCN    55
# HND    55
# Name: Country Code, dtype: int64

# %%
# Remove the rows with missing data
cleanBlank = WorldBankDrop.dropna(how="any")
cleanBlank.count()
# Out:
# Country Name     275
# Country Code     275
# Series Name      275
# 2011 [YR2011]    275
# 2012 [YR2012]    275
# 2013 [YR2013]    275
# 2014 [YR2014]    275
# 2015 [YR2015]    275
# 2016 [YR2016]    275
# 2017 [YR2017]    275
# 2018 [YR2018]    275
# dtype: int64

# %%
cleanBlank
# Out:
#                   Country Name Country Code  \
# 0    Latin America & Caribbean          LCN
# 1    Latin America & Caribbean          LCN
# 2    Latin America & Caribbean          LCN
# 3    Latin America & Caribbean          LCN
# 4    Latin America & Caribbean          LCN
# ..                         ...          ...
# 270                  Nicaragua          NIC
# 271                  Nicaragua          NIC
# 272                  Nicaragua          NIC
# 273                  Nicaragua          NIC
# 274                  Nicaragua          NIC
#
#                                            Series Name     2011 [YR2011]  \
# 0                                    Population, total         596538911
# 1                         Population growth (annual %)   1.1198476558079
# 2                                Surface area (sq. km)  20425484.4078087
# 3    Population density (people per sq. km of land ...  29.7641321747825
# 4    Poverty headcount ratio at national poverty li...                ..
# ..                                                 ...               ...
# 270  Total debt service (% of exports of goods, ser...  16.5034812629961
# 271                                      Net migration                ..
# 272       Personal remittances, received (current US$)         913600000
# 273  Foreign direct investment, net inflows (BoP, c...         936300000
# 274  Net official development assistance and offici...  536580017.089844
#
#         2012 [YR2012]     2013 [YR2013]     2014 [YR2014]     2015 [YR2015]  \
# 0           603097381         609600087         616002686         622301089
# 1    1.09942031928911  1.07821824548762   1.0502949616541  1.02246356114104
# 2    20425482.3765587  20425483.3921837  20425483.3921837  20425483.3921837
# 3    30.0919866753081  30.4198271919214  30.7396318936835  31.0539334286253
# 4                  ..                ..                ..                ..
# ..                ...               ...               ...               ...
# 270  13.1993935702772   12.619058858323  13.0433478797368  15.4249727683352
# 271           -135020                ..                ..                ..
# 272        1016300000        1081300000        1140200000        1197500000
# 273         767700000         815500000         884100000         949900000
# 274  532320007.324219  495799987.792969  432170013.427734  457920013.427734
#
#          2016 [YR2016]      2017 [YR2017]      2018 [YR2018]
# 0            628484873          634545282          640454810
# 1    0.993696477365475  0.964288761807637  0.931301227451243
# 2     20426078.3765625   20426078.3765625   20425545.9765625
# 3      31.362515271189   31.6649404813693   31.9606855829336
# 4                   ..                 ..                 ..
# ..                 ...                ...                ...
# 270   15.9334779279193   19.8201596232055   19.0280490011247
# 271                 ..            -106360                 ..
# 272         1268100000         1394700000         1504800000
# 273          898700000          771900000          359200000
# 274   430980010.986328   562590026.855469   351950012.207031
#
# [275 rows x 11 columns]

# %%
cleanBlank2 = cleanBlank.drop(cleanBlank[(cleanBlank['Country Code'] == 'LCN')].index)

# %%
cleanBlank2
# Out:
#     Country Name Country Code  \
# 55    Costa Rica          CRI
# 56    Costa Rica          CRI
# 57    Costa Rica          CRI
# 58    Costa Rica          CRI
# 59    Costa Rica          CRI
# ..           ...          ...
# 270    Nicaragua          NIC
# 271    Nicaragua          NIC
# 272    Nicaragua          NIC
# 273    Nicaragua          NIC
# 274    Nicaragua          NIC
#
#                                            Series Name     2011 [YR2011]  \
# 55                                   Population, total           4633086
# 56                        Population growth (annual %)  1.20968236400613
# 57                               Surface area (sq. km)             51100
# 58   Population density (people per sq. km of land ...  90.7380728554642
# 59   Poverty headcount ratio at national poverty li...              21.7
# ..                                                 ...               ...
# 270  Total debt service (% of exports of goods, ser...  16.5034812629961
# 271                                      Net migration                ..
# 272       Personal remittances, received (current US$)         913600000
# 273  Foreign direct investment, net inflows (BoP, c...         936300000
# 274  Net official development assistance and offici...  536580017.089844
#
#         2012 [YR2012]     2013 [YR2013]     2014 [YR2014]     2015 [YR2015]  \
# 55            4688000           4742107           4795396           4847804
# 56   1.17828835259712  1.14754994327846  1.11747392449788  1.08695279543583
# 57              51100             51100             51100             51100
# 58   91.8135526831179  92.8732275754015  93.9168820994908  94.9432824128476
# 59               20.6              20.7              22.4              21.7
# ..                ...               ...               ...               ...
# 270  13.1993935702772   12.619058858323  13.0433478797368  15.4249727683352
# 271           -135020                ..                ..                ..
# 272        1016300000        1081300000        1140200000        1197500000
# 273         767700000         815500000         884100000         949900000
# 274  532320007.324219  495799987.792969  432170013.427734  457920013.427734
#
#         2016 [YR2016]     2017 [YR2017]     2018 [YR2018]
# 55            4899345           4949954           4999441
# 56   1.05757038052655  1.02767608960277  0.99478225758881
# 57              51100             51100             51100
# 58   95.9527027027027  96.9438699569134  97.9130630630631
# 59               20.5                20              21.1
# ..                ...               ...               ...
# 270  15.9334779279193  19.8201596232055  19.0280490011247
# 271                ..           -106360                ..
# 272        1268100000        1394700000        1504800000
# 273         898700000         771900000         359200000
# 274  430980010.986328  562590026.855469  351950012.207031
#
# [220 rows x 11 columns]

# %%
cleanBlank2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', '2011 [YR2011]',
#        '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]',
#        '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
BankRename = cleanBlank2.rename(columns={'Country Name': 'country_name', 'Country Code' : 'country_code', 'Series Name': 'series_name','2011 [YR2011]': 'yr2011', '2012 [YR2012]': 'yr2012', '2013 [YR2013]': 'yr2013', '2014 [YR2014]' : 'yr2014', '2015 [YR2015]' : 'yr2015', '2016 [YR2016]' : 'yr2016', '2017 [YR2017]' : 'yr2017', '2018 [YR2018]' : 'yr2018'  })

# %%
BankRename
# Out:
#     country_name country_code  \
# 55    Costa Rica          CRI
# 56    Costa Rica          CRI
# 57    Costa Rica          CRI
# 58    Costa Rica          CRI
# 59    Costa Rica          CRI
# ..           ...          ...
# 270    Nicaragua          NIC
# 271    Nicaragua          NIC
# 272    Nicaragua          NIC
# 273    Nicaragua          NIC
# 274    Nicaragua          NIC
#
#                                            series_name            yr2011  \
# 55                                   Population, total           4633086
# 56                        Population growth (annual %)  1.20968236400613
# 57                               Surface area (sq. km)             51100
# 58   Population density (people per sq. km of land ...  90.7380728554642
# 59   Poverty headcount ratio at national poverty li...              21.7
# ..                                                 ...               ...
# 270  Total debt service (% of exports of goods, ser...  16.5034812629961
# 271                                      Net migration                ..
# 272       Personal remittances, received (current US$)         913600000
# 273  Foreign direct investment, net inflows (BoP, c...         936300000
# 274  Net official development assistance and offici...  536580017.089844
#
#                yr2012            yr2013            yr2014            yr2015  \
# 55            4688000           4742107           4795396           4847804
# 56   1.17828835259712  1.14754994327846  1.11747392449788  1.08695279543583
# 57              51100             51100             51100             51100
# 58   91.8135526831179  92.8732275754015  93.9168820994908  94.9432824128476
# 59               20.6              20.7              22.4              21.7
# ..                ...               ...               ...               ...
# 270  13.1993935702772   12.619058858323  13.0433478797368  15.4249727683352
# 271           -135020                ..                ..                ..
# 272        1016300000        1081300000        1140200000        1197500000
# 273         767700000         815500000         884100000         949900000
# 274  532320007.324219  495799987.792969  432170013.427734  457920013.427734
#
#                yr2016            yr2017            yr2018
# 55            4899345           4949954           4999441
# 56   1.05757038052655  1.02767608960277  0.99478225758881
# 57              51100             51100             51100
# 58   95.9527027027027  96.9438699569134  97.9130630630631
# 59               20.5                20              21.1
# ..                ...               ...               ...
# 270  15.9334779279193  19.8201596232055  19.0280490011247
# 271                ..           -106360                ..
# 272        1268100000        1394700000        1504800000
# 273         898700000         771900000         359200000
# 274  430980010.986328  562590026.855469  351950012.207031
#
# [220 rows x 11 columns]

# %%
BankRename['country_name'].value_counts()
# Out:
# Honduras       55
# Costa Rica     55
# Nicaragua      55
# El Salvador    55
# Name: country_name, dtype: int64

# %%
BankRename.columns
# Out:
# Index(['country_name', 'country_code', 'series_name', 'yr2011', 'yr2012',
#        'yr2013', 'yr2014', 'yr2015', 'yr2016', 'yr2017', 'yr2018'],
#       dtype='object')

# %%
BankRename2 = BankRename[['country_name', 'series_name', 'yr2011', 'yr2012', 'yr2013',
       'yr2014', 'yr2015', 'yr2016', 'yr2017', 'yr2018']]

# %%
BankRename2
# Out:
#     country_name                                        series_name  \
# 55    Costa Rica                                  Population, total
# 56    Costa Rica                       Population growth (annual %)
# 57    Costa Rica                              Surface area (sq. km)
# 58    Costa Rica  Population density (people per sq. km of land ...
# 59    Costa Rica  Poverty headcount ratio at national poverty li...
# ..           ...                                                ...
# 270    Nicaragua  Total debt service (% of exports of goods, ser...
# 271    Nicaragua                                      Net migration
# 272    Nicaragua       Personal remittances, received (current US$)
# 273    Nicaragua  Foreign direct investment, net inflows (BoP, c...
# 274    Nicaragua  Net official development assistance and offici...
#
#                yr2011            yr2012            yr2013            yr2014  \
# 55            4633086           4688000           4742107           4795396
# 56   1.20968236400613  1.17828835259712  1.14754994327846  1.11747392449788
# 57              51100             51100             51100             51100
# 58   90.7380728554642  91.8135526831179  92.8732275754015  93.9168820994908
# 59               21.7              20.6              20.7              22.4
# ..                ...               ...               ...               ...
# 270  16.5034812629961  13.1993935702772   12.619058858323  13.0433478797368
# 271                ..           -135020                ..                ..
# 272         913600000        1016300000        1081300000        1140200000
# 273         936300000         767700000         815500000         884100000
# 274  536580017.089844  532320007.324219  495799987.792969  432170013.427734
#
#                yr2015            yr2016            yr2017            yr2018
# 55            4847804           4899345           4949954           4999441
# 56   1.08695279543583  1.05757038052655  1.02767608960277  0.99478225758881
# 57              51100             51100             51100             51100
# 58   94.9432824128476  95.9527027027027  96.9438699569134  97.9130630630631
# 59               21.7              20.5                20              21.1
# ..                ...               ...               ...               ...
# 270  15.4249727683352  15.9334779279193  19.8201596232055  19.0280490011247
# 271                ..                ..           -106360                ..
# 272        1197500000        1268100000        1394700000        1504800000
# 273         949900000         898700000         771900000         359200000
# 274  457920013.427734  430980010.986328  562590026.855469  351950012.207031
#
# [220 rows x 10 columns]

# %%
rds_connection_string = "admin1:12345@localhost:5432/ETL_Gary_and_Maria"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2337         try:
# -> 2338             return fn()
#    2339         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#
# ~/opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  database "ETL_Gary_and_Maria" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-155-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in table_names(self, schema, connection)
#    2316         """
#    2317
# -> 2318         with self._optional_conn_ctx_manager(connection) as conn:
#    2319             return self.dialect.get_table_names(conn, schema)
#    2320
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _optional_conn_ctx_manager(self, connection)
#    2086     def _optional_conn_ctx_manager(self, connection=None):
#    2087         if connection is None:
# -> 2088             with self._contextual_connect() as conn:
#    2089                 yield conn
#    2090         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2302         return self._connection_cls(
#    2303             self,
# -> 2304             self._wrap_pool_connect(self.pool.connect, None),
#    2305             close_with_result=close_with_result,
#    2306             **kwargs
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2340             if connection is None:
#    2341                 Connection._handle_dbapi_exception_noconnection(
# -> 2342                     e, dialect, self
#    2343                 )
#    2344             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1582         elif should_wrap:
#    1583             util.raise_(
# -> 1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#    1586         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2336         dialect = self.dialect
#    2337         try:
# -> 2338             return fn()
#    2339         except dialect.dbapi.Error as e:
#    2340             if connection is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
#      68                 compat.raise_(
# ---> 69                     exc_value, with_traceback=exc_tb,
#      70                 )
#      71         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     491     def connect(self, *cargs, **cparams):
#     492         # inherits the docstring from interfaces.Dialect.connect
# --> 493         return self.dbapi.connect(*cargs, **cparams)
#     494
#     495     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  database "ETL_Gary_and_Maria" does not exist
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-65c7b136cd66> in <module>
# ----> 1 new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)
#
# NameError: name 'new_customer_data_df' is not defined
