# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# %%
url = 'https://api.kivaws.org/graphql?query=%7B%0A%20%20lend%20%7B%0A%20%20%20%20loans(filters%3A%20%7Bcountry%3A%20%5B%22NI%22%2C%20%22SV%22%2C%20%22HN%22%2C%20%22CR%22%5D%7D)%20%7B%0A%20%20%20%20%20%20totalCount%0A%20%20%20%20%20%20values%20%7B%0A%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20loanAmount%0A%20%20%20%20%20%20%20%20image%20%7B%0A%20%20%20%20%20%20%20%20%20%20url(presetSize%3A%20small)%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20activity%20%7B%0A%20%20%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20geocode%20%7B%0A%20%20%20%20%20%20%20%20%20%20country%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20isoCode%0A%20%20%20%20%20%20%20%20%20%20%20%20name%0A%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20lenders(limit%3A%200)%20%7B%0A%20%20%20%20%20%20%20%20%20%20totalCount%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20...%20on%20LoanPartner%20%7B%0A%20%20%20%20%20%20%20%20%20%20partnerName%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20...%20on%20LoanDirect%20%7B%0A%20%20%20%20%20%20%20%20%20%20trusteeName%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%7D%0A%7D%0A&variables=null&operationName=null'

# %%
req=requests.get(url)
response = req.json()

# %%
response
# Out:
# {'data': {'lend': {'loans': {'totalCount': 625,
#     'values': [{'name': 'Eusebio',
#       'loanAmount': '600.00',
#       'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/706a41091e59e8cf3e4a01bc08a51de5.jpg'},
#       'activity': {'name': 'Farming'},
#       'geocode': {'country': {'isoCode': 'SV', 'name': 'El Salvador'}},
#       'lenders': {'totalCount': 8},
#       'partnerName': 'CrediCampo'},
#      {'name': 'Santos Adrian',
#       'loanAmount': '450.00',
#       'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/5cde6b3110f7af15b132e84ae2319cce.jpg'},
#       'activity': {'name': 'Pigs'},
#       'geocode': {'country': {'isoCode': 'HN', 'name': 'Honduras'}},
#       'lenders': {'totalCount': 9},
#       'partnerName': 'Organizacion de Desarrollo Empresarial Femenino (ODEF)'},
#      {'name': 'G.s La Unión Malguara 2 Group',
#       'loanAmount': '975.00',
# ...

# %%
json = json.loads(json.dumps(response))
clean_json = json['data']['lend']['loans']['values']
# clean_df = pd.DataFrame(clean_df)

# %%
clean_json
# Out:
# [{'name': 'Eusebio',
#   'loanAmount': '600.00',
#   'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/706a41091e59e8cf3e4a01bc08a51de5.jpg'},
#   'activity': {'name': 'Farming'},
#   'geocode': {'country': {'isoCode': 'SV', 'name': 'El Salvador'}},
#   'lenders': {'totalCount': 8},
#   'partnerName': 'CrediCampo'},
#  {'name': 'Santos Adrian',
#   'loanAmount': '450.00',
#   'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/5cde6b3110f7af15b132e84ae2319cce.jpg'},
#   'activity': {'name': 'Pigs'},
#   'geocode': {'country': {'isoCode': 'HN', 'name': 'Honduras'}},
#   'lenders': {'totalCount': 9},
#   'partnerName': 'Organizacion de Desarrollo Empresarial Femenino (ODEF)'},
#  {'name': 'G.s La Unión Malguara 2 Group',
#   'loanAmount': '975.00',
#   'image': {'url': 'https://www-kiva-org-0.freetls.fastly.net/img/s50/94f2ef54ff843e28090355518dda650d.jpg'},
#   'activity': {'name': 'Farming'},
# ...

# %%
df = pd.DataFrame(clean_json)

# %%
df
# Out:
#                              name loanAmount  \
# 0                         Eusebio     600.00
# 1                   Santos Adrian     450.00
# 2   G.s La Unión Malguara 2 Group     975.00
# 3             Todo Poderoso Group     850.00
# 4                       José Edis     800.00
# 5               Magdaleno Antonio     800.00
# 6                 Willian Ernesto    1000.00
# 7                      Blanca Luz     450.00
# 8                      Yosel Paul    1275.00
# 9           Jardin Del Eden Group     900.00
# 10                  María Pastora     800.00
# 11                   Emma Yolanda     425.00
# 12                    Juan Carlos    1000.00
# 13                   Zulma Haydeé     900.00
# 14                        Grettel    1775.00
# 15                         Odilia     700.00
# 16                 Zayda Lissette    1500.00
# 17                  Santos Benito     500.00
# 18                 Gladis Yamilex    1300.00
# 19                   Edwin Samuel     400.00
#
# ...
