# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
kiva_loans_path="loans.csv"

# %%
kiva_loans_df=pd.read_csv(kiva_loans_path)

# %%
kiva_loans_df
# Out:
#          LOAN_ID                    LOAN_NAME ORIGINAL_LANGUAGE  \
# 0         372964                      JENELYN           English
# 1        1037234                      Zohra\t           English
# 2        1037493              Suma Inti Group           Spanish
# 3        1800053                        Irene           English
# 4         542923  Duo Perlas De Ramirez Group           Spanish
# ...          ...                          ...               ...
# 1926369   584713                          NaN               NaN
# 1926370   774723                         Ajan           English
# 1926371   627247                 Yuris Alexis           Spanish
# 1926372  1657590                      Medardo           Spanish
# 1926373  1614873                        Tanya           English
#
#                                                DESCRIPTION  \
# 0        At the age of 20, Jenelyn is married and has o...
# 1        Zohra is a housewife with four children residi...
# ...

# %%
kiva_lenders_path="lenders.csv"
kiva_lenders_df=pd.read_csv(kiva_lenders_path)
kiva_lenders_df
# Out:
#                  PERMANENT_NAME                          DISPLAY_NAME  \
# 0        farmcreditservices3158  Farm Credit Services of Colusa Glenn
# 1                    yuelin1988                                Yuelin
# 2                 james90768901                                 James
# 3                   malinda9944                               Malinda
# 4                     marlo9389                                 Marlo
# ...                         ...                                   ...
# 1511819             kirsten8180                               Kirsten
# 1511820           fieldmechanic                                 Peter
# 1511821        daveanddonna8938                        Dave and Donna
# 1511822              daniel3694                                Daniel
# 1511823           wendy61528265                                 Wendy
#
#          MAIN_PIC_ID             CITY                STATE COUNTRY_CODE  \
# ...

# %%
kiva_loan_lenders_path="loans_lenders.csv"
kiva_loan_lenders_df=pd.read_csv(kiva_loan_lenders_path)
kiva_loan_lenders_df
# Out:
#          LOAN_ID                                            LENDERS
# 0         130894  joanne6368, russ6120, chun3169, justin9596, di...
# 1         304332  elsie6249, kristian9091, michael3526, brett233...
# 2         510444  chris5768, katy1098, ernie9037, greg1731, kati...
# 3         257214  makoto3762, makoto3762, carsten6736, Verdad, j...
# 4         263909  yaar4748, kevin7345, sri2960, april7878, david...
# ...          ...                                                ...
# 1878244  1476603  gautam9529, davidandsusan9466, kevin4031, kati...
# 1878245  1476869  nms, carrieann1356, tim4327, sandy2372, samuel...
# 1878246  1476671                  nms, nicola7221, themissionbeltco
# 1878247  1461005  themissionbeltco, alex7206, abbey5211, will817...
# 1878248  1477635  mark71583909, drken7723, Echelaunch, themissio...
#
# [1878249 rows x 2 columns]
