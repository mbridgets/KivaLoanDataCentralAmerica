# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from sqlalchemy import create_engine

# %%
# csv path
kiva_loans_path="Data Sets/kiva_loans_clean"

# %%
kiva_loans_df=pd.read_csv(kiva_loans_path)

# %% [markdown]
# # Notes for Grader
# The code in the next two cells was used in the shrink_csv.csv filed to make our CSV file smaller in order to add the file to Github.

# %%
# only keep columns with pertinant data
# kiva_loans_clean_df = kiva_loans_df[['LOAN_ID', 'LOAN_NAME',
#        'FUNDED_AMOUNT', 'LOAN_AMOUNT', 'STATUS', 'ACTIVITY_NAME', 'SECTOR_NAME',
#        'COUNTRY_CODE', 'COUNTRY_NAME', 'TOWN_NAME', 'CURRENCY',
#        'DISBURSE_TIME', 'LENDER_TERM', 'NUM_LENDERS_TOTAL',
#        'BORROWER_GENDERS', 'REPAYMENT_INTERVAL']]

# %%
# get data for only the four countries 

# kiva_country =  kiva_loans_df[(kiva_loans_df['COUNTRY_CODE'] == 'CR')|(kiva_loans_df['COUNTRY_CODE'] == 'SV')|(kiva_loans_df['COUNTRY_CODE'] == 'HN')|(kiva_loans_df['COUNTRY_CODE'] == 'NI')]

# %%
# drop no info 
kiva_country_clean = kiva_loans_df.dropna()

# %%
kiva_country_clean = kiva_country_clean.drop(columns='COUNTRY_CODE')

# %%
kiva_country_clean = kiva_country_clean.drop(columns='Unnamed: 0')

# %%
# check what date the data begins
kiva_country_clean.sort_values(by=['DISBURSE_TIME'])
# Out:
#         LOAN_ID            LOAN_NAME  FUNDED_AMOUNT  LOAN_AMOUNT  STATUS  \
# 149321      206      Eli Oved Zepeda          400.0        400.0  funded
# 160762      244  Pastor David Suarez          250.0        250.0  funded
# 127390      155          Maria Elena          200.0        200.0  funded
# 56939       220                 Alba          350.0        350.0  funded
# 26485       236  Ramona Suyapa Zeron          175.0        175.0  funded
# ...         ...                  ...            ...          ...     ...
# 47044   1962779          Hector Jose          450.0        450.0  funded
# 58645   1962338      Antonio Orfilio         1000.0       1000.0  funded
# 91007   1962340           Roger Omar          800.0        800.0  funded
# 148204  1962608               Corina          750.0        750.0  funded
# 156875  1963278                Denis          750.0        750.0  funded
#
#          ACTIVITY_NAME  SECTOR_NAME COUNTRY_NAME      TOWN_NAME CURRENCY  \
# 149321      Shoe Sales       Retail     Honduras   Siguatepeque      USD
# 160762        Pharmacy       Health     Honduras          Danli      USD
# 127390       Tailoring     Services    Nicaragua        Managua      USD
# 56939   Clothing Sales     Clothing     Honduras          Danli      USD
# 26485           Bakery         Food     Honduras          Danli      USD
# ...                ...          ...          ...            ...      ...
# 47044          Farming  Agriculture    Nicaragua         Wiwili      USD
# 58645    Farm Supplies  Agriculture    Nicaragua  Nueva Segovia      USD
# 91007    Farm Supplies  Agriculture    Nicaragua  Nueva Segovia      USD
# 148204         Farming  Agriculture    Nicaragua      Matagalpa      USD
# 156875         Farming  Agriculture    Nicaragua  Nueva Segovia      USD
#
#                         DISBURSE_TIME  LENDER_TERM  NUM_LENDERS_TOTAL  \
# 149321  2005-04-14 05:27:55.000 +0000         12.0                  8
# 160762  2005-04-14 05:27:55.000 +0000         12.0                  5
# 127390  2005-04-14 05:27:55.000 +0000          4.0                  1
# 56939   2005-04-14 05:27:55.000 +0000         12.0                  2
# 26485   2005-04-14 05:27:55.000 +0000         12.0                  1
# ...                               ...          ...                ...
# 47044   2020-05-22 07:00:00.000 +0000         14.0                 17
# 58645   2020-05-22 07:00:00.000 +0000         14.0                 37
# 91007   2020-05-22 07:00:00.000 +0000         14.0                  5
# 148204  2020-05-23 07:00:00.000 +0000         14.0                  2
# 156875  2020-05-25 07:00:00.000 +0000         14.0                 30
#
#        BORROWER_GENDERS REPAYMENT_INTERVAL
# 149321           female            monthly
# 160762             male            monthly
# 127390           female            monthly
# 56939            female            monthly
# 26485            female            monthly
# ...                 ...                ...
# 47044              male             bullet
# 58645              male             bullet
# 91007              male             bullet
# 148204           female             bullet
# 156875             male             bullet
#
# [119302 rows x 15 columns]

# %%
# rename columns
kiva_country_clean = kiva_country_clean.rename(columns={
    'LOAN_ID': 'loan_id',
    'LOAN_NAME': 'loan_name',
    'FUNDED_AMOUNT':'amount_funded',
    'LOAN_AMOUNT':'loan_amount',
    'STATUS': 'loan_status',
    'ACTIVITY_NAME': 'activity_name',
    'SECTOR_NAME':'sector_name',
    'COUNTRY_NAME':'country_name',
    'TOWN_NAME':'town_name',
    'CURRENCY': 'currency',
    'DISBURSE_TIME':'dispursement_date',
    'LENDER_TERM':'length_of_loan',
    'NUM_LENDERS_TOTAL':'total_number_of_lenders',
    'BORROWER_GENDERS':'borrower_gender',
    'REPAYMENT_INTERVAL':'repayment_interval'
})

# %%
kiva_country_clean_df = kiva_country_clean[(kiva_country_clean['borrower_gender'] == 'male')|(kiva_country_clean['borrower_gender'] == 'female')]

# %%
# connect to SQL
rds_connection_string = "admin1:12345@localhost:5432/ETL_Gary_and_Maria"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['kiva_data', 'worldbank_data']

# %%
# Export DF to SQL table
kiva_country_clean_df.to_sql(name='kiva_data', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from kiva_data', con=engine).head()
# Out:
#    loan_id          loan_name  amount_funded  loan_amount loan_status  \
# 0   419930           Wilfredo          350.0        350.0      funded
# 1   923021  Denis Noe Antonio          650.0       1000.0     expired
# 2  1616035       Reina Isabel          800.0        800.0      funded
# 3   355527  Williams Aguistin         1025.0       1025.0      funded
# 4   868483      Blanca Lyliam          300.0        300.0      funded
#
#                activity_name  sector_name country_name  \
# 0             Clothing Sales     Clothing  El Salvador
# 1                  Livestock  Agriculture  El Salvador
# 2                    Poultry  Agriculture  El Salvador
# 3                   Services     Services    Nicaragua
# 4  Personal Medical Expenses       Health  El Salvador
#
#                        town_name currency              dispursement_date  \
# 0  San Francisco Gotera, Morazan      USD  2012-04-03 07:00:00.000 +0000
# 1                  Sensuntepeque      USD  2015-06-26 07:00:00.000 +0000
# 2                    San Vicente      USD  2018-09-11 07:00:00.000 +0000
# 3                           Leon      NIO  2011-10-31 07:00:00.000 +0000
# 4                    El Transito      USD  2015-04-08 07:00:00.000 +0000
#
#    length_of_loan  total_number_of_lenders borrower_gender repayment_interval
# 0            14.0                        7            male            monthly
# 1            17.0                       14            male            monthly
# 2            20.0                       24          female            monthly
# 3            21.0                       36            male            monthly
# 4            12.0                       12          female            monthly
